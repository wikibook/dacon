# %%
import pandas as pd
# csv 형식으로 된 파일을 읽어옵니다.
train = pd.read_csv('../data/train.csv') 
test = pd.read_csv('../data/test.csv')
print("train shape is", train.shape)
print("test shape is", test.shape)
# Out:
# train shape is (810000, 230)
# test shape is (10000, 227)

# %%
train.head()
# Out:
#    layer_1  layer_2  layer_3  layer_4         0         1         2         3  \
# 0       10       10       10       10  0.254551  0.258823  0.254659  0.252085
# 1       10       10       10       20  0.205062  0.225544  0.217758  0.202169
# 2       10       10       10       30  0.189196  0.165869  0.177655  0.156822
# 3       10       10       10       40  0.131003  0.120076  0.138975  0.117931
# 4       10       10       10       50  0.091033  0.086893  0.108125  0.080405
#
#           4         5  ...       216       217       218       219       220  \
# 0  0.247678  0.253614  ...  0.354750  0.369223  0.388184  0.408496  0.414564
# 1  0.199633  0.207380  ...  0.557203  0.573656  0.587998  0.612754  0.627825
# 2  0.175094  0.177755  ...  0.699864  0.708688  0.721982  0.713464  0.743030
# 3  0.130566  0.131262  ...  0.764786  0.763788  0.770017  0.787571  0.778866
# 4  0.105917  0.077083  ...  0.786677  0.802271  0.806557  0.799614  0.789333
#
#         221       222       223       224       225
# 0  0.429403  0.419225  0.443250  0.433414  0.465502
# 1  0.633393  0.637706  0.625981  0.653231  0.637853
# 2  0.741709  0.747743  0.746037  0.737356  0.750391
# 3  0.776969  0.774712  0.801526  0.805305  0.784057
# 4  0.804087  0.787763  0.794948  0.819105  0.801781
#
# [5 rows x 230 columns]

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 810000 entries, 0 to 809999
# Columns: 230 entries, layer_1 to 225
# dtypes: float64(226), int64(4)
# memory usage: 1.4 GB

# %%
train.loc[:,'0':'225'].describe()
# Out:
#                    0              1              2              3  \
# count  810000.000000  810000.000000  810000.000000  810000.000000
# mean        0.292653       0.292893       0.293125       0.293363
# std         0.181642       0.181857       0.182055       0.182197
# min        -0.014902      -0.014798      -0.014897      -0.014709
# 25%         0.135139       0.135180       0.135258       0.135478
# 50%         0.286510       0.286874       0.287194       0.287553
# 75%         0.435696       0.435956       0.436112       0.436326
# max         0.748205       0.753103       0.749494       0.747389
#
#                    4              5              6              7  \
# count  810000.000000  810000.000000  810000.000000  810000.000000
# mean        0.293666       0.293994       0.294344       0.294792
# std         0.182361       0.182529       0.182693       0.182858
# min        -0.014903      -0.014662      -0.014924      -0.014789
# 25%         0.135585       0.135705       0.135858       0.136423
# 50%         0.287830       0.288151       0.288705       0.289222
# 75%         0.436634       0.437142       0.437395       0.437924
# max         0.748827       0.750392       0.751105       0.749795
#
#                    8              9  ...            216            217  \
# count  810000.000000  810000.000000  ...  810000.000000  810000.000000
# mean        0.295325       0.295757  ...       0.600336       0.606206
# std         0.183057       0.183192  ...       0.199727       0.198644
# min        -0.014775      -0.014945  ...      -0.011992      -0.008661
# 25%         0.136704       0.136993  ...       0.469345       0.476970
# 50%         0.289905       0.290652  ...       0.643685       0.649886
# 75%         0.438657       0.439172  ...       0.760737       0.765462
# max         0.751538       0.750883  ...       0.935423       0.934867
#
#                  218            219            220            221  \
# count  810000.000000  810000.000000  810000.000000  810000.000000
# mean        0.612238       0.618456       0.623942       0.625395
# std         0.197473       0.196177       0.195028       0.194909
# min        -0.011430      -0.009827      -0.007632      -0.007411
# 25%         0.484727       0.492739       0.500232       0.501650
# 50%         0.656258       0.662860       0.668727       0.670287
# 75%         0.770333       0.775263       0.779555       0.780846
# max         0.938873       0.937817       0.942214       0.940367
#
#                  222            223            224            225
# count  810000.000000  810000.000000  810000.000000  810000.000000
# mean        0.627100       0.628997       0.631166       0.633594
# std         0.194730       0.194493       0.194146       0.193725
# min        -0.007073      -0.007101      -0.005519      -0.006074
# 25%         0.503811       0.506252       0.509036       0.512067
# 50%         0.672145       0.674283       0.676692       0.679339
# 75%         0.782387       0.783979       0.785774       0.787759
# max         0.940387       0.941548       0.942411       0.943648
#
# [8 rows x 226 columns]

# %%
test.describe()
# Out:
#                 id             0             1             2             3  \
# count  10000.00000  10000.000000  10000.000000  10000.000000  10000.000000
# mean    4999.50000      0.298620      0.298523      0.298266      0.298122
# std     2886.89568      0.182323      0.182546      0.182835      0.183146
# min        0.00000     -0.014062     -0.014153     -0.013073     -0.013437
# 25%     2499.75000      0.143776      0.142043      0.141642      0.140117
# 50%     4999.50000      0.292133      0.291344      0.291543      0.291320
# 75%     7499.25000      0.440783      0.441728      0.441065      0.442691
# max     9999.00000      0.738145      0.735195      0.730482      0.727110
#
#                   4             5             6             7             8  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean       0.297840      0.297781      0.297680      0.297628      0.297761
# std        0.183721      0.183892      0.184473      0.185290      0.185560
# min       -0.013738     -0.013458     -0.013132     -0.014418     -0.013239
# 25%        0.139429      0.138310      0.138377      0.136580      0.136497
# 50%        0.291687      0.291404      0.290600      0.290009      0.292850
# 75%        0.443197      0.443525      0.443969      0.445480      0.446458
# max        0.739487      0.740530      0.739367      0.746795      0.739782
#
#        ...           216           217           218           219  \
# count  ...  10000.000000  10000.000000  10000.000000  10000.000000
# mean   ...      0.601752      0.607483      0.613193      0.618859
# std    ...      0.200110      0.198799      0.198037      0.197150
# min    ...     -0.000326     -0.000018     -0.001248     -0.006506
# 25%    ...      0.470463      0.475866      0.486420      0.493853
# 50%    ...      0.644588      0.651759      0.658020      0.663477
# 75%    ...      0.762421      0.767317      0.770799      0.775913
# max    ...      0.922739      0.922250      0.924994      0.920316
#
#                 220           221           222           223           224  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean       0.623699      0.624553      0.625722      0.627125      0.628886
# std        0.196688      0.197329      0.197532      0.197626      0.197022
# min        0.007479      0.007074      0.003891      0.000749      0.010466
# 25%        0.497811      0.500310      0.504392      0.502767      0.504647
# 50%        0.669354      0.670082      0.672555      0.674006      0.675324
# 75%        0.780854      0.782970      0.783460      0.784899      0.785543
# max        0.930631      0.928891      0.935706      0.935085      0.937052
#
#                 225
# count  10000.000000
# mean       0.631377
# std        0.196373
# min        0.001458
# 25%        0.509042
# 50%        0.677706
# 75%        0.787843
# max        0.940716
#
# [8 rows x 227 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
hist_0 = train.iloc[:,4:5]
hist_1 = train.iloc[:,5:6]
hist_2 = train.iloc[:,6:7]
hist_3 = train.iloc[:,7:8]
# 시각화를 위한 축과 크기를 설정합니다.
f, axes = plt.subplots(2,2, figsize=(9,9), sharex=True)

# 보기 편하게 왼쪽 및 아래쪽 축을 제거합니다.
sns.despine(left=True)
# 각각의 분포를 4개로 나누어 함께 찍어봅니다
sns.distplot(hist_0, kde=True, color="r", ax=axes[0,0])
sns.distplot(hist_1, kde=True, color="g", ax=axes[0,1])
sns.distplot(hist_2, kde=True, color="b", ax=axes[1,0])
sns.distplot(hist_3, kde=True, color="y", ax=axes[1,1])
plt.show()

# %%
# 다양한 분포에서 랜덤 제너레이터를 지원하는 라이브러리를 호출합니다.
from random import * 

# 랜덤으로 4~230 사이의 정수 4개를 뽑습니다.
random_number = randint(4,230)
print(random_number)
     
hist_0 = train.iloc[:,random_number:random_number+1]

random_number = randint(4,230)
print(random_number)
hist_1 = train.iloc[:,random_number:random_number+1]

random_number = randint(4,230)
print(random_number)
hist_2 = train.iloc[:,random_number:random_number+1]

random_number = randint(4,230)
print(random_number)
hist_3 = train.iloc[:,random_number:random_number+1]

f, axes = plt.subplots(2,2, figsize=(9,9), sharex=True)

sns.despine(left=True)
sns.distplot(hist_0, kde=True, color="r", ax=axes[0,0])
sns.distplot(hist_1, kde=True, color="g", ax=axes[0,1])
sns.distplot(hist_2, kde=True, color="b", ax=axes[1,0])
sns.distplot(hist_3, kde=True, color="y", ax=axes[1,1])

plt.show()
# Out:
# 230
# 224
# 79
# 199
# C:\Users\sk8er\anaconda3\lib\site-packages\numpy\lib\histograms.py:908: RuntimeWarning: invalid value encountered in true_divide
#   return n/db/n.sum(), bin_edges

# %%
fig, ax = plt.subplots(figsize=(16,6))   
sns.countplot(x="layer_1", data=train)
plt.title("layer_1 thickness histogram")
plt.show()

# %%
fig, ax = plt.subplots(figsize=(16,6))   
sns.countplot(x="layer_2", data=train)
plt.title("layer_2 thickness histogram")
plt.show()

# %%
fig, ax = plt.subplots(figsize=(16,6))   
sns.countplot(x="layer_3", data=train)
plt.title("layer_3 thickness histogram")
plt.show()

# %%
fig, ax = plt.subplots(figsize=(16,6))   
sns.countplot(x="layer_4", data=train)
plt.title("layer_4 thickness histogram")
plt.show()

# %%
cor = train.corr()   # train 데이터 컬럼 간의 상관관계를 구합니다.
# cor.loc['layer_1':'layer_4','0':'225']는 상관계수로부터 layer_1~layer_4에 해당하는 행과 반사율 스펙트럼에 해당하는 '0':'225'행만을 선택합니다.
# style.background_gradient()로 판다스 display()의 출력 결과표에 수치에 따라 서로 다른 배경색을 칠할 수 있습니다.
# cmap은 컬러맵을 의미합니다. 'coolwarm'은 파란색에서 빨간색으로 변하는 컬러맵입니다.
# set_precision(2)으로 설정해 소수점 아래 둘째 자리까지만 값을 출력해 보겠습니다.    
display(cor.loc['layer_1':'layer_4','0':'225'].style.background_gradient(cmap='coolwarm').set_precision(2))
# Out:
# <style  type="text/css" >
#     #T_e7dd5e2a_298f_11eb_a0f8_6c6a77fbaa49row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_e7dd5e2a_298f_11eb_a0f8_6c6a77fbaa49row0_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_e7dd5e2a_298f_11eb_a0f8_6c6a77fbaa49row0_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_e7dd5e2a_298f_11eb_a0f8_6c6a77fbaa49row0_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_e7dd5e2a_298f_11eb_a0f8_6c6a77fbaa49row0_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_e7dd5e2a_298f_11eb_a0f8_6c6a77fbaa49row0_col5 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_e7dd5e2a_298f_11eb_a0f8_6c6a77fbaa49row0_col6 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_e7dd5e2a_298f_11eb_a0f8_6c6a77fbaa49row0_col7 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_e7dd5e2a_298f_11eb_a0f8_6c6a77fbaa49row0_col8 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_e7dd5e2a_298f_11eb_a0f8_6c6a77fbaa49row0_col9 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_e7dd5e2a_298f_11eb_a0f8_6c6a77fbaa49row0_col10 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_e7dd5e2a_298f_11eb_a0f8_6c6a77fbaa49row0_col11 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_e7dd5e2a_298f_11eb_a0f8_6c6a77fbaa49row0_col12 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_e7dd5e2a_298f_11eb_a0f8_6c6a77fbaa49row0_col13 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_e7dd5e2a_298f_11eb_a0f8_6c6a77fbaa49row0_col14 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_e7dd5e2a_298f_11eb_a0f8_6c6a77fbaa49row0_col15 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_e7dd5e2a_298f_11eb_a0f8_6c6a77fbaa49row0_col16 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_e7dd5e2a_298f_11eb_a0f8_6c6a77fbaa49row0_col17 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_e7dd5e2a_298f_11eb_a0f8_6c6a77fbaa49row0_col18 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_e7dd5e2a_298f_11eb_a0f8_6c6a77fbaa49row0_col19 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_e7dd5e2a_298f_11eb_a0f8_6c6a77fbaa49row0_col20 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_e7dd5e2a_298f_11eb_a0f8_6c6a77fbaa49row0_col21 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_e7dd5e2a_298f_11eb_a0f8_6c6a77fbaa49row0_col22 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_e7dd5e2a_298f_11eb_a0f8_6c6a77fbaa49row0_col23 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_e7dd5e2a_298f_11eb_a0f8_6c6a77fbaa49row0_col24 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_e7dd5e2a_298f_11eb_a0f8_6c6a77fbaa49row0_col25 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_e7dd5e2a_298f_11eb_a0f8_6c6a77fbaa49row0_col26 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_e7dd5e2a_298f_11eb_a0f8_6c6a77fbaa49row0_col27 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_e7dd5e2a_298f_11eb_a0f8_6c6a77fbaa49row0_col28 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_e7dd5e2a_298f_11eb_a0f8_6c6a77fbaa49row0_col29 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_e7dd5e2a_298f_11eb_a0f8_6c6a77fbaa49row0_col30 {
#             background-color:  #bd1f2d;
#             color:  #f1f1f1;
#         }    #T_e7dd5e2a_298f_11eb_a0f8_6c6a77fbaa49row0_col31 {
#             background-color:  #cf453c;
#             color:  #f1f1f1;
#         }    #T_e7dd5e2a_298f_11eb_a0f8_6c6a77fbaa49row0_col32 {
#             background-color:  #e16751;
#             color:  #000000;
#         }    #T_e7dd5e2a_298f_11eb_a0f8_6c6a77fbaa49row0_col33 {
#             background-color:  #ee8669;
#             color:  #000000;
#         }    #T_e7dd5e2a_298f_11eb_a0f8_6c6a77fbaa49row0_col34 {
#             background-color:  #f7a889;
#             color:  #000000;
#         }    #T_e7dd5e2a_298f_11eb_a0f8_6c6a77fbaa49row0_col35 {
#             background-color:  #f3c8b2;
#             color:  #000000;
#         }    #T_e7dd5e2a_298f_11eb_a0f8_6c6a77fbaa49row0_col36 {
#             background-color:  #d8dce2;
#             color:  #000000;
#         }    #T_e7dd5e2a_298f_11eb_a0f8_6c6a77fbaa49row0_col37 {
#             background-color:  #a5c3fe;
#             color:  #000000;
#         }    #T_e7dd5e2a_298f_11eb_a0f8_6c6a77fbaa49row0_col38 {
#             background-color:  #7093f3;
#             color:  #000000;
#         }    #T_e7dd5e2a_298f_11eb_a0f8_6c6a77fbaa49row0_col39 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_e7dd5e2a_298f_11eb_a0f8_6c6a77fbaa49row0_col40 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_e7dd5e2a_298f_11eb_a0f8_6c6a77fbaa49row0_col41 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_e7dd5e2a_298f_11eb_a0f8_6c6a77fbaa49row0_col42 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_e7dd5e2a_298f_11eb_a0f8_6c6a77fbaa49row0_col43 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_e7dd5e2a_298f_11eb_a0f8_6c6a77fbaa49row0_col44 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_e7dd5e2a_298f_11eb_a0f8_6c6a77fbaa49row0_col45 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_e7dd5e2a_298f_11eb_a0f8_6c6a77fbaa49row0_col46 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_e7dd5e2a_298f_11eb_a0f8_6c6a77fbaa49row0_col47 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_e7dd5e2a_298f_11eb_a0f8_6c6a77fbaa49row0_col48 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_e7dd5e2a_298f_11eb_a0f8_6c6a77fbaa49row0_col49 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_e7dd5e2a_298f_11eb_a0f8_6c6a77fbaa49row0_col50 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_e7dd5e2a_298f_11eb_a0f8_6c6a77fbaa49row0_col51 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_e7dd5e2a_298f_11eb_a0f8_6c6a77fbaa49row0_col52 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_e7dd5e2a_298f_11eb_a0f8_6c6a77fbaa49row0_col53 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_e7dd5e2a_298f_11eb_a0f8_6c6a77fbaa49row0_col54 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_e7dd5e2a_298f_11eb_a0f8_6c6a77fbaa49row0_col55 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_e7dd5e2a_298f_11eb_a0f8_6c6a77fbaa49row0_col56 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_e7dd5e2a_298f_11eb_a0f8_6c6a77fbaa49row0_col57 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_e7dd5e2a_298f_11eb_a0f8_6c6a77fbaa49row0_col58 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_e7dd5e2a_298f_11eb_a0f8_6c6a77fbaa49row0_col59 {
#             background

# %%
# 앞서 계산했던 전체 데이터의 상관관계 계수 테이블로부터 반사율 스펙트럼에 해당하는 행과 열만 선택합니다.
col_relation=cor.loc['0':'225','0':'225']
# figsize =(16,16)은 16인치*16인치 사이즈를 의미합니다.
fig, ax = plt.subplots(figsize=(16,16))   
# 반사율 스펙트럼 변수 간의 상관관계 테이블의 숫자를 색으로 표현하는 히트맵을 만들어 줍니다.
# cmap='RdBu'은 빨강~파랑 컬러맵을 뜻하고, annot=False로 지정해 테이블이 지저분하지 않게 수치 값을 출력하지 않았습니다. 상관관계 계수가 0이 될 때를 중심으로 상관관계를 살펴보고 싶으므로 컬러맵의 중앙을 의미하는 center 값을 0으로 지정합니다.
sns.heatmap(col_relation, annot=False, cmap="RdBu", center=0)
plt.show()

# %%
null_check_train = train.isnull().sum()
null_check_test = test.isnull().sum()
print(null_check_train[null_check_train>0])
print(null_check_test[null_check_test>0])
# Out:
# Series([], dtype: int64)
# Series([], dtype: int64)
